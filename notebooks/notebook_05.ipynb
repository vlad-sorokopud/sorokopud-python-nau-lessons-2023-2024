# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
im = cv2.imread('img1.png')
img = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_GRAY2RGB))

# %%
n = 10

for i in range(200, 200 + n):
    for j in range(200, 200 + n):
        v = img[i,j]
        if v < 10:
            v = "00" + str(v)
        elif v < 100:
            v = "0" + str(v)
        print(v, end=" ")
    print()
# Out:
# 077 072 082 078 074 073 071 067 064 074
# 068 068 080 091 087 084 069 068 077 098
# 077 082 084 082 064 070 077 087 087 098
# 085 072 073 070 065 065 097 090 078 072
# 076 067 060 061 066 086 099 090 073 059
# 065 058 063 069 081 091 090 079 060 053
# 063 073 070 087 098 094 094 085 062 059
# 073 083 082 102 093 105 102 066 058 051
# 083 095 090 096 096 104 081 069 054 051
# 077 089 100 098 100 090 064 067 057 054

# %%
o1 = np.array([[0, 0, 0], [0, 0.5, 0], [0, 0, 0]], dtype=np.float32)

w,h = img.shape
img_r1 = img.copy()

#print(img_r1[i,j])

# v1 
# for x in range(1, w - 1):
#     for y in range(1, h -1):
#         v = o1[0][0]*img[x-1,y-1]+o1[0][1]*img[x,y-1]+o1[0][2]*img[x+1,y-1] \
#         +o1[1][0]*img[x-1,y]+o1[1][1]*img[x,y]+o1[1][2]*img[x+1,y] \
#         +o1[2][0]*img[x-1,y+1]+o1[2][1]*img[x,y+1]+o1[2][2]*img[x+1,y+1]

#         #print(v)
#         img_r1[x,y] = v

# v2.1
# for x in range(1, w - 1):
#     for y in range(1, h -1):
#         v = 0
#         for i in range(3):  
#             for j in range(3):
#                 v += o1[i][j]*img[x-1+i,y-1+j]

#         img_r1[i,j] = v

# v2.2
# for x in range(1, w - 1):
#     for y in range(1, h -1):
#         v = 0
#         for i in range(-1,2):  # i: -1 0 1   fox img => x + i     for o1 i+1 -> 0 1 2  
#             for j in range(-1, 2):
#                 v += o1[i+1][j+1]*img[x+i,y+j]

#         img_r1[i,j] = v

# v3 
img_r1 = cv2.filter2D(img, -1, o1)

# %%
plt.imshow(cv2.cvtColor(img_r1, cv2.COLOR_GRAY2RGB))

# %%
o2 = np.array([[0, 0, 0], [0, 1.5, 0], [0, 0, 0]], dtype=np.float32)
plt.imshow(cv2.cvtColor(cv2.filter2D(img, -1, o2), cv2.COLOR_GRAY2RGB))

# %%
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
o2 = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]], dtype=np.float32)
im_r2 = cv2.filter2D(im, -1, o2)
plt.imshow(cv2.cvtColor(im_r2, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite('img_0.jpeg',im_r2)
# Out:
# True
