# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ages = df["Age"]

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.loc[150]
# Out:
# PassengerId                           151
# Survived                                0
# Pclass                                  2
# Name           Bateman, Rev. Robert James
# Sex                                  male
# Age                                  51.0
# SibSp                                   0
# Parch                                   0
# Ticket                        S.O.P. 1166
# Fare                               12.525
# Cabin                                 NaN
# Embarked                                S
# Name: 150, dtype: object

# %%
df.loc[120:130]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 120          121         0       2   Hickman, Mr. Stanley George    male
# 121          122         0       3    Moore, Mr. Leonard Charles    male
# 122          123         0       2          Nasser, Mr. Nicholas    male
# 123          124         1       2           Webber, Miss. Susan  female
# 124          125         0       1   White, Mr. Percival Wayland    male
# 125          126         1       3  Nicola-Yarred, Master. Elias    male
# 126          127         0       3           McMahon, Mr. Martin    male
# 127          128         1       3     Madsen, Mr. Fridtjof Arne    male
# 128          129         1       3             Peter, Miss. Anna  female
# 129          130         0       3            Ekstrom, Mr. Johan    male
# 130          131         0       3          Drazenoic, Mr. Jozef    male
#
#       Age  SibSp  Parch        Ticket     Fare  Cabin Embarked
# ...

# %%
df.loc[120:130, "Name"]
# Out:
# 120     Hickman, Mr. Stanley George
# 121      Moore, Mr. Leonard Charles
# 122            Nasser, Mr. Nicholas
# 123             Webber, Miss. Susan
# 124     White, Mr. Percival Wayland
# 125    Nicola-Yarred, Master. Elias
# 126             McMahon, Mr. Martin
# 127       Madsen, Mr. Fridtjof Arne
# 128               Peter, Miss. Anna
# 129              Ekstrom, Mr. Johan
# 130            Drazenoic, Mr. Jozef
# Name: Name, dtype: object

# %%
df.loc[120:130, ["Pclass", "Age"]]
# Out:
#      Pclass   Age
# 120       2  21.0
# 121       3   NaN
# 122       2  32.5
# 123       2  32.5
# 124       1  54.0
# 125       3  12.0
# 126       3   NaN
# 127       3  24.0
# 128       3   NaN
# 129       3  45.0
# 130       3  33.0

# %%
df.iloc[120:130, 2:]
# Out:
#      Pclass                          Name     Sex   Age  SibSp  Parch  \
# 120       2   Hickman, Mr. Stanley George    male  21.0      2      0
# 121       3    Moore, Mr. Leonard Charles    male   NaN      0      0
# 122       2          Nasser, Mr. Nicholas    male  32.5      1      0
# 123       2           Webber, Miss. Susan  female  32.5      0      0
# 124       1   White, Mr. Percival Wayland    male  54.0      0      1
# 125       3  Nicola-Yarred, Master. Elias    male  12.0      1      0
# 126       3           McMahon, Mr. Martin    male   NaN      0      0
# 127       3     Madsen, Mr. Fridtjof Arne    male  24.0      0      0
# 128       3             Peter, Miss. Anna  female   NaN      1      1
# 129       3            Ekstrom, Mr. Johan    male  45.0      0      0
#
#            Ticket     Fare  Cabin Embarked
# 120  S.O.C. 14879  73.5000    NaN        S
# 121     A4. 54510   8.0500    NaN        S
# 122        237736  30.0708    NaN        C
# ...

# %%
df[df["Age"] > 29]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
values1 = [
    df[df["Sex"] == "male"]["Sex"].count(),
    df[df["Sex"] == "female"]["Sex"].count()
]

# %%
lables1 = ["male", "female"]


plt.pie(values1, labels=lables1, autopct='%1.1f%%')
plt.show()

# %%
sex_report1 = df.groupby("Sex")["Sex"].count()

# %%
sex_report1
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
plt.pie(sex_report1.values, labels=sex_report1.index, autopct='%1.1f%%')
plt.show()

# %%
#h_mean = df["Age"].mean()
#df_where_h_age_mean = df[df["Age"] > h_mean]

df2 = df[df["Age"] < 18]
sex_report_2 =  df2.groupby("Sex")["Sex"].count()

plt.pie(sex_report_2.values, labels=sex_report_2.index, autopct='%1.1f%%')
plt.show()

# %%
df.fillna(4)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.groupby("Sex")["Age"].mean()

# %%
df.groupby("Pclass")["Age"].mean()

# %%
plt.figure(figsize=(12, 2))

plt.subplot(121)
plt.hist(df[df["Sex"] == "male"]["Age"], color="blue")

plt.subplot(122)
plt.hist(df[df["Sex"] == "female"]["Age"], color="red")

plt.show()

# %%
df["Age"] # => df.Age

# %%
df.groupby("Pclass")["Age"].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(12, 2))

plt.subplot(121)
plt.hist(df[df["Sex"] == "male"]["Age"], color="blue")

plt.subplot(122)
plt.hist(df[df["Sex"] == "female"]["Age"], color="red")

plt.show()

# %%
df["Age"] # => df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
